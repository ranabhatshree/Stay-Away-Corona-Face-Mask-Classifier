# %%
import tensorflow as tf
import os
import numpy as np
import cv2
import keras
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob

# %%
train_dir = 'data/'
os.listdir(train_dir)
# Out:
# ['no_mask', 'with_mask']

# %%
# defining paramters
fast_run = False
batch_size = 8
img_height = 150
img_width = 150
img_channels = 3

# %%
# loading data

labels_dict = {
    'no_mask': 0,
    'with_mask': 1,
}

def load_data():
    """
    Loads data and preprocess. Returns train and test data along with labels.
    """
    images = []
    labels = []
    size = img_width,img_height
    print("LOADING DATA FROM : ",end = "")
    for folder in os.listdir(train_dir):
        print(folder, end = ' | ')
        for image in os.listdir(train_dir + "/" + folder):
            temp_img = cv2.imread(train_dir + '/' + folder + '/' + image)
            if(type(temp_img) is np.ndarray):
                temp_img = cv2.resize(temp_img, size)
                images.append(temp_img)
                labels.append(labels_dict[folder])
    
    images = np.array(images)
    labels = np.array(labels)
    
    # saving numpy file
    np.save('images.npy', images)
    np.save('labels.npy', labels)
    print('Numpy file saved success...')
    
    # Normalizing image data.
    images = images.astype('float32')/255.0
    
    # converting labels to one hot format.

    labels = keras.utils.to_categorical(labels)
    
    # creating training and test data by splitting original data into 70% of training data and 30% testing data.
    X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size = 0.3)
    
    print()
    print('Loaded', len(X_train),'images for training,','Train data shape =',X_train.shape)
    print('Loaded', len(X_test),'images for testing','Test data shape =',X_test.shape)
    
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = load_data()
# Out:
# LOADING DATA FROM : no_mask | with_mask | Numpy file saved success...
#
# Loaded 714 images for training, Train data shape = (714, 150, 150, 3)
# Loaded 306 images for testing Test data shape = (306, 150, 150, 3)

# %%
# define model

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, img_channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 148, 148, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 72, 72, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 34, 34, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               18940416
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 19,037,634
# Trainable params: 19,036,162
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# compile model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [earlystop, learning_rate_reduction]

# %%
epochs= 50
history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, validation_split = 0.3)
# Out:
# Train on 499 samples, validate on 215 samples
# Epoch 1/50
# 499/499 [==============================] - 139s 279ms/step - loss: 1.3319 - accuracy: 0.5952 - val_loss: 9.1107 - val_accuracy: 0.4837
# Epoch 2/50
# 499/499 [==============================] - 131s 263ms/step - loss: 0.9150 - accuracy: 0.6433 - val_loss: 0.6881 - val_accuracy: 0.5628
# Epoch 3/50
# 499/499 [==============================] - 138s 277ms/step - loss: 0.8478 - accuracy: 0.6774 - val_loss: 6.3957 - val_accuracy: 0.4837
# Epoch 4/50
# 499/499 [==============================] - 142s 284ms/step - loss: 0.8385 - accuracy: 0.6994 - val_loss: 0.6559 - val_accuracy: 0.6465
# Epoch 5/50
# 499/499 [==============================] - 143s 286ms/step - loss: 0.8077 - accuracy: 0.6693 - val_loss: 1.0981 - val_accuracy: 0.5581
# Epoch 6/50
# Epoch 42/50
# 499/499 [==============================] - 147s 295ms/step - loss: 0.1456 - accuracy: 0.9359 - val_loss: 0.9451 - val_accuracy: 0.6930
# Epoch 43/50
# 499/499 [==============================] - 146s 293ms/step - loss: 0.1772 - accuracy: 0.9499 - val_loss: 0.9398 - val_accuracy: 0.6837
# Epoch 44/50
# 499/499 [==============================] - 146s 292ms/step - loss: 0.2021 - accuracy: 0.9178 - val_loss: 0.9429 - val_accuracy: 0.6884
# Epoch 45/50
# 499/499 [==============================] - 147s 295ms/step - loss: 0.2026 - accuracy: 0.9359 - val_loss: 1.4972 - val_accuracy: 0.6698
# Epoch 46/50
# 499/499 [==============================] - 146s 293ms/step - loss: 0.1994 - accuracy: 0.9299 - val_loss: 1.3464 - val_accuracy: 0.7163
# Epoch 47/50
# 499/499 [==============================] - 146s 292ms/step - loss: 0.1540 - accuracy: 0.9459 - val_loss: 1.1046 - val_accuracy: 0.7116
# Epoch 48/50
# 499/499 [==============================] - 146s 293ms/step - loss: 0.1181 - accuracy: 0.9539 - val_loss: 1.2805 - val_accuracy: 0.7488
# Epoch 49/50
# 499/499 [==============================] - 146s 293ms/step - loss: 0.1396 - accuracy: 0.9599 - val_loss: 1.0346 - val_accuracy: 0.7256
# Epoch 50/50
# 499/499 [==============================] - 146s 293ms/step - loss: 0.1182 - accuracy: 0.9519 - val_loss: 0.9740 - val_accuracy: 0.7163

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train', 'test'], loc='lower right')
plt.title('accuracy plot - train vs test')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training loss', 'validation loss'], loc = 'upper right')
plt.title('loss plot - training vs vaidation')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
evaluate_metrics = model.evaluate(X_test, Y_test)
print("\nEvaluation Accuracy = ", "{:.2f}%".format(evaluate_metrics[1]*100),"\nEvaluation loss = " ,"{:.6f}".format(evaluate_metrics[0]))
# Out:
# 306/306 [==============================] - 20s 65ms/step
#
# Evaluation Accuracy =  64.38%
# Evaluation loss =  1.323337

# %%
# Saving the model
model_json = model.to_json()
with open("model/model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights('model/model.h5')
print('model saved success')
# Out:
# model saved success

# %%
labels =[ label for label in labels_dict]

# %%
def plot_n_predict(img_path):
    img = imread(os.path.join('testing_images', img_path))
    plt.imshow(img)
    img = cv2.resize(img, (img_width, img_height))
    img = img.reshape(1, img_width, img_height, 3)
    my_pred = np.argmax(model.predict(img))
    pred_class = labels[my_pred]
    plt.title(pred_class)
    plt.show()

# %%
plot_n_predict('mz.jpg')

# %%
plot_n_predict('mz_1.jpg')
# Out:
# [[1. 0.]]

# %%
plot_n_predict('mz_2.jpg')
# Out:
# [[1. 0.]]

# %%
plot_n_predict('donald.jpg')
# Out:
# [[1. 0.]]

# %%
plot_n_predict('image.jpeg')

# %%
plot_n_predict('donald_1.jpg')

# %%
plot_n_predict('kpoli.jpg')
